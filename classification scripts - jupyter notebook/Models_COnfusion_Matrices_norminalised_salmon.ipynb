# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Confusion matrix data from the image
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [202,  14,    9,   3],
    [  0, 206,    1,  45],
    [273,  93, 1134, 110],
    [  0,   3,    0,  45]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('FishCNN - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the 'Optimised FishCNN' image
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 190,    7,   31,    0],
    [   6,  226,   15,    5],
    [  49,   19, 1532,   10],
    [   0,    4,    5,   39]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Optimised FishCNN (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the MLP results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 154,    6,   68,    0],
    [   2,  236,    9,    5],
    [  49,   20, 1537,    4],
    [   0,    6,    4,   38]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('MLP - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the SVM (RBF) results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 211,   10,    7,    0],
    [   1,  238,    1,   12],
    [ 171,   51, 1371,   17],
    [   0,    3,    0,   45]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('SVM (RBF) - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the KNN results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 104,    6,  118,    0],
    [   0,  228,   13,   11],
    [  29,   12, 1565,    4],
    [   0,    9,   11,   28]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('KNN - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the XGBoost results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 121,    9,   98,    0],
    [   1,  225,   22,    4],
    [  19,    6, 1584,    1],
    [   0,    6,    8,   34]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('XGBoost - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the AdaBoost results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [   3,   15,  210,    0],
    [   0,  108,  144,    0],
    [   5,   54, 1551,    0],
    [   0,   29,   19,    0]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('AdaBoost - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Extra Trees results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 105,   16,  107,    0],
    [   0,  236,   10,    6],
    [  21,   37, 1548,    4],
    [   0,    9,    4,   35]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Extra Trees - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Random Forest results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [  87,   16,  125,    0],
    [   0,  225,   22,    5],
    [  12,   20, 1576,    2],
    [   0,    9,   12,   27]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Random Forest - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Decision Tree results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 127,    9,   92,    0],
    [   1,  208,   30,   13],
    [ 118,   46, 1420,   26],
    [   1,    9,    7,   31]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Decision Tree - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Gaussian NB results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [139,   0,  72,  17],
    [  0, 181,   5,  66],
    [320, 185, 988, 117],
    [  0,   5,   2,  41]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Gaussian NB - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Logistic Regression results
# Rows: True, Columns: Predicted [agitation, clustering, normal, other]
cm = np.array([
    [ 196,    6,   23,    3],
    [   4,  220,    7,   21],
    [ 230,   83, 1267,   30],
    [   0,    6,    1,   41]
])

classes = ['agitation', 'clustering', 'normal', 'other']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Logistic Regression - Salmon Behaviour Classification (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion matrix data from the Optimised FishCNN - Background Study
# Rows/Columns order: agitation, background, clustering, normal
cm = np.array([
    [ 182,    0,    8,   38],
    [   0,  300,    0,    0],
    [   1,    0,  238,   13],
    [  48,    0,   15, 1547]
])

classes = ['agitation', 'background', 'clustering', 'normal']

# Row normalization (true label normalization)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plotting
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='viridis', 
            xticklabels=classes, yticklabels=classes, vmin=0, vmax=1)
plt.title('Optimised FishCNN - Background Study (Normalized)')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

classes = [
    "Background",
    "Agitation",
    "Clustering",
    "Normal"
]

confusion_matrices = {

    "Logistic Regression": np.array([
        [300, 0,   0,    0],
        [0, 190,   4,   34],
        [0,   2, 240,   10],
        [0, 250,  85, 1275]
    ]),

    "Gaussian NB": np.array([
        [297,   3,   0,    0],
        [0,   147,  11,   70],
        [0,     0, 245,    7],
        [0,   307, 301, 1002]
    ]),

    "Decision Tree": np.array([
        [300,   0,   0,    0],
        [0,   146,   4,   78],
        [0,     6, 207,   39],
        [0,   146,  44, 1420]
    ]),

    "Random Forest": np.array([
        [300,   0,   0,    0],
        [0,   105,   7,  116],
        [0,     0, 231,   21],
        [0,    15,  17, 1578]
    ]),

    "Extra Trees": np.array([
        [300,   0,   0,    0],
        [0,   114,   7,  107],
        [0,     0, 245,    7],
        [0,    23,  30, 1557]
    ]),

    "AdaBoost": np.array([
        [300,   0,   0,    0],
        [0,    28,   3,  197],
        [0,     0, 128,  124],
        [0,    64,  60, 1486]
    ]),

    "XGBoost": np.array([
        [300,   0,   0,    0],
        [0,   134,   3,   91],
        [0,     0, 235,   17],
        [0,    19,  11, 1580]
    ]),

    "KNN": np.array([
        [300,   0,   0,    0],
        [0,   112,   3,  113],
        [0,     3, 228,   21],
        [0,    35,  15, 1560]
    ]),

    "SVM (RBF)": np.array([
        [300,   0,   0,    0],
        [0,   218,   3,    7],
        [0,     4, 246,    2],
        [0,   169,  73, 1368]
    ]),

    "MLP": np.array([
        [300,   0,   0,    0],
        [0,   165,   0,   63],
        [0,     7, 232,   13],
        [0,    32,   3, 1575]
    ]),

    "Optimized FishCNN": np.array([
        [300,   0,   0,    0],
        [0,   182,   8,   38],
        [0,     1, 238,   13],
        [0,    48,  15, 1547]
    ])
}

for model_name, cm in confusion_matrices.items():

    cm_norm = (
        cm.astype(float)
        /
        cm.sum(axis=1)[:, np.newaxis]
    )

    plt.figure(figsize=(8, 6))

    sns.heatmap(
        cm_norm,
        annot=True,
        fmt=".2f",
        cmap="viridis",
        xticklabels=classes,
        yticklabels=classes,
        vmin=0,
        vmax=1
    )

    plt.title(
        f"{model_name} - Background Study (Normalized)"
    )

    plt.ylabel("True")
    plt.xlabel("Predicted")

    plt.tight_layout()

    filename = (
        model_name
        .replace(" ", "_")
        .replace("(", "")
        .replace(")", "")
        + "_background_norm_cm.png"
    )

    plt.savefig(
        filename,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(f"Saved: {filename}")

print("\nAll normalized confusion matrices generated.")
# Out:
# Saved: Logistic_Regression_background_norm_cm.png
# Saved: Gaussian_NB_background_norm_cm.png
# Saved: Decision_Tree_background_norm_cm.png
# Saved: Random_Forest_background_norm_cm.png
# Saved: Extra_Trees_background_norm_cm.png
# Saved: AdaBoost_background_norm_cm.png
# Saved: XGBoost_background_norm_cm.png
# Saved: KNN_background_norm_cm.png
# Saved: SVM_RBF_background_norm_cm.png
# Saved: MLP_background_norm_cm.png
# Saved: Optimized_FishCNN_background_norm_cm.png
#
# All normalized confusion matrices generated.
